# %%
import pickle
import pandas as pd

# %%
from sklearn.metrics import root_mean_squared_error

# %%
file_path = 'models/lin_reg.bin'

try:
    with open(file_path, 'rb') as file_in: # 'rb' for read binary
        # Load the objects. pickle.load() will return exactly what you dumped.
        # Since we dumped a tuple (dv, lr), it will return that tuple.
        dv, lr = pickle.load(file_in)

    # Now you can use dv_loaded and lr_loaded
    print("Objects loaded successfully!")
    print("Type of dv_loaded:", type(dv))
    print("Type of lr_loaded:", type(lr))

    # Example: If dv_loaded is a DictVectorizer, you might check its vocabulary
    # if hasattr(dv_loaded, 'vocabulary_'):
    #     print("dv_loaded vocabulary size:", len(dv_loaded.vocabulary_))

    # Example: If lr_loaded is a scikit-learn model, you might check its coefficients
    # if hasattr(lr_loaded, 'coef_'):
    #     print("lr_loaded coefficients:", lr_loaded.coef_)

except FileNotFoundError:
    print(f"Error: The file '{file_path}' was not found. Make sure the path is correct.")
except pickle.UnpicklingError:
    print(f"Error: Could not unpickle the file '{file_path}'. It might be corrupted or not a pickle file.")
except ImportError as e:
    print(f"Error: A class definition needed for unpickling is missing: {e}")
    print("Ensure all necessary libraries (e.g., scikit-learn) are installed and imported.")
except Exception as e:
    print(f"An unexpected error occurred: {e}")
# Out:
# Objects loaded successfully!
# Type of dv_loaded: <class 'sklearn.feature_extraction._dict_vectorizer.DictVectorizer'>
# Type of lr_loaded: <class 'sklearn.linear_model._base.LinearRegression'>

# %%
def read_dataframe(filename):
    if filename.endswith('.csv'):
        df = pd.read_csv(filename)

        df.lpep_dropoff_datetime = pd.to_datetime(df.lpep_dropoff_datetime)
        df.lpep_pickup_datetime = pd.to_datetime(df.lpep_pickup_datetime)
    elif filename.endswith('.parquet'):
        df = pd.read_parquet(filename)

    df['duration'] = df.lpep_dropoff_datetime - df.lpep_pickup_datetime
    df.duration = df.duration.apply(lambda td: td.total_seconds() / 60)

    df = df[(df.duration >= 1) & (df.duration <= 60)]

    categorical = ['PULocationID', 'DOLocationID']
    df[categorical] = df[categorical].astype(str)
    
    return df
df_train = read_dataframe('../data/green_tripdata_2021-01.parquet')
df_val = read_dataframe('../data/green_tripdata_2021-02.parquet')
df_train['PU_DO'] = df_train['PULocationID'] + '_' + df_train['DOLocationID']
df_val['PU_DO'] = df_val['PULocationID'] + '_' + df_val['DOLocationID']
target = 'duration'
y_train = df_train[target].values
y_val = df_val[target].values

# %%
df_train = read_dataframe('../data/green_tripdata_2021-01.parquet')
df_val = read_dataframe('../data/green_tripdata_2021-02.parquet')

# %%
df_train['PU_DO'] = df_train['PULocationID'] + '_' + df_train['DOLocationID']
df_val['PU_DO'] = df_val['PULocationID'] + '_' + df_val['DOLocationID']

categorical = ['PU_DO'] #'PULocationID', 'DOLocationID']
numerical = ['trip_distance']

# dv = DictVectorizer()

train_dicts = df_train[categorical + numerical].to_dict(orient='records')
# X_train = dv.fit_transform(train_dicts) # dv is already fit / loaded from pickled file
X_train = dv.transform(train_dicts)

val_dicts = df_val[categorical + numerical].to_dict(orient='records')
X_val = dv.transform(val_dicts)

target = 'duration'
y_train = df_train[target].values
y_val = df_val[target].values

# %%
try: 
    X_train, y_train, X_val, y_val, dv, lr
    print('all objects loaded successfully')
except NameError: print('objects missing')
# Out:
# all objects loaded successfully

# %%
train = xgb.DMatrix(X_train, label=y_train)
valid = xgb.DMatrix(X_val, label=y_val)

# %% [markdown]
# LOGGING

# %%
import mlflow
mlflow.set_tracking_uri('sqlite:///mlflow.db')
mlflow.set_experiment('nyc_taxi_experiment_2_4')

import xgboost as xgb

# %%
import mlflow.xgboost

with mlflow.start_run():

    # best_params = {
    #     "learning_rate": 0.06250345613117511,
    #     "max_depth": 43,
    #     "min_child_weight": 1.4898346923239079,
    #     "objective": "reg:linear",
    #     "reg_alpha": 0.013267037520848521,
    #     "reg_lambda": 0.005200771650703148,
    #     "seed": 42
    #     }
    
    best_params = {
    "learning_rate": 0.17846516109979893,
    "max_depth": 43,
    "min_child_weight": 1.3599886311054774,
    "objective": "reg:linear",
    "reg_alpha": 0.10102327187602764,
    "reg_lambda": 0.33287636923295955,
    "seed": 42
}

    mlflow.log_params(best_params)

    # mlflow.xgboost.autolog()

    booster = xgb.train(
        params=best_params,
        dtrain=train,
        num_boost_round=1000,   
        evals=[(valid, 'validation')],
        early_stopping_rounds=50)
    
    y_pred = booster.predict(valid)
    rmse = root_mean_squared_error(y_val, y_pred)

    mlflow.log_metric('rmse', rmse)

    with open('models/preprocessor.b', 'wb') as f_out:
        pickle.dump(dv, f_out)

    mlflow.log_artifact('models/preprocessor.b', artifact_path='preprocessor')

    mlflow.xgboost.log_model(booster, artifact_path='models_mlflow')
# Out:
# /Users/matthiasmotl/opt/anaconda3/envs/experiment_tracking/lib/python3.9/site-packages/xgboost/core.py:160: UserWarning: [14:27:49] WARNING: /Users/runner/miniforge3/conda-bld/xgboost-split_1703076406455/work/src/objective/regression_obj.cu:209: reg:linear is now deprecated in favor of reg:squarederror.
#   warnings.warn(smsg, UserWarning)
# [0]	validation-rmse:10.79100
# [1]	validation-rmse:9.70032
# [2]	validation-rmse:8.87296
# [3]	validation-rmse:8.25867
# [4]	validation-rmse:7.80031
# [5]	validation-rmse:7.46694
# [6]	validation-rmse:7.22031
# [7]	validation-rmse:7.03847
# [8]	validation-rmse:6.90785
# [9]	validation-rmse:6.80955
# [10]	validation-rmse:6.73655
# [11]	validation-rmse:6.68127
# [12]	validation-rmse:6.64016
# [13]	validation-rmse:6.60587
# [14]	validation-rmse:6.57795
# [15]	validation-rmse:6.55628
# [16]	validation-rmse:6.54059
# [17]	validation-rmse:6.52702
# [18]	validation-rmse:6.51484
# [19]	validation-rmse:6.50552
# [20]	validation-rmse:6.49747
# [21]	validation-rmse:6.49167
# [22]	validation-rmse:6.48647
# [23]	validation-rmse:6.48204
# [24]	validation-rmse:6.47747
# [25]	validation-rmse:6.47459
# [26]	validation-rmse:6.47236
# [27]	validation-rmse:6.47108
# [28]	validation-rmse:6.46950
# [29]	validation-rmse:6.46756
# [30]	validation-rmse:6.46562
# [31]	validation-rmse:6.46331
# [32]	validation-rmse:6.46156
# [33]	validation-rmse:6.45992
# [34]	validation-rmse:6.45736
# [35]	validation-rmse:6.45538
# [36]	validation-rmse:6.45355
# [37]	validation-rmse:6.45261
# [38]	validation-rmse:6.45113
# [39]	validation-rmse:6.45029
# [40]	validation-rmse:6.44912
# [41]	validation-rmse:6.44735
# [42]	validation-rmse:6.44630
# [43]	validation-rmse:6.44484
# [44]	validation-rmse:6.44299
# [45]	validation-rmse:6.44123
# [46]	validation-rmse:6.44015
# [47]	validation-rmse:6.43879
# [48]	validation-rmse:6.43667
# [49]	validation-rmse:6.43508
# [50]	validation-rmse:6.43367
# [51]	validation-rmse:6.43218
# [52]	validation-rmse:6.43080
# [53]	validation-rmse:6.42982
# [54]	validation-rmse:6.42876
# [55]	validation-rmse:6.42727
# [56]	validation-rmse:6.42587
# [57]	validation-rmse:6.42478
# [58]	validation-rmse:6.42392
# [59]	validation-rmse:6.42306
# [60]	validation-rmse:6.42214
# [61]	validation-rmse:6.42060
# [62]	validation-rmse:6.41970
# [63]	validation-rmse:6.41904
# [64]	validation-rmse:6.41799
# [65]	validation-rmse:6.41763
# [66]	validation-rmse:6.41671
# [67]	validation-rmse:6.41519
# [68]	validation-rmse:6.41417
# [69]	validation-rmse:6.41315
# [70]	validation-rmse:6.41196
# [71]	validation-rmse:6.41097
# [72]	validation-rmse:6.41012
# [73]	validation-rmse:6.40917
# [74]	validation-rmse:6.40811
# [75]	validation-rmse:6.40693
# [76]	validation-rmse:6.40600
# [77]	validation-rmse:6.40518
# [78]	validation-rmse:6.40355
# [79]	validation-rmse:6.40279
# [80]	validation-rmse:6.40186
# [81]	validation-rmse:6.40085
# [82]	validation-rmse:6.39957
# [83]	validation-rmse:6.39926
# [84]	validation-rmse:6.39886
# [85]	validation-rmse:6.39807
# [86]	validation-rmse:6.39701
# [87]	validation-rmse:6.39666
# [88]	validation-rmse:6.39634
# [89]	validation-rmse:6.39548
# [90]	validation-rmse:6.39436
# [91]	validation-rmse:6.39330
# [92]	validation-rmse:6.39293
# [93]	validation-rmse:6.39227
# [94]	validation-rmse:6.39160
# [95]	validation-rmse:6.39123
# [96]	validation-rmse:6.39090
# [97]	validation-rmse:6.39021
# [98]	validation-rmse:6.38986
# [99]	validation-rmse:6.38961
# [100]	validation-rmse:6.38900
# [101]	validation-rmse:6.38813
# [102]	validation-rmse:6.38740
# [103]	validation-rmse:6.38662
# [104]	validation-rmse:6.38578
# [105]	validation-rmse:6.38512
# [106]	validation-rmse:6.38446
# [107]	validation-rmse:6.38413
# [108]	validation-rmse:6.38334
# [109]	validation-rmse:6.38274
# [110]	validation-rmse:6.38172
# [111]	validation-rmse:6.38081
# [112]	validation-rmse:6.37980
# [113]	validation-rmse:6.37929
# [114]	validation-rmse:6.37871
# [115]	validation-rmse:6.37844
# [116]	validation-rmse:6.37761
# [117]	validation-rmse:6.37708
# [118]	validation-rmse:6.37594
# [119]	validation-rmse:6.37543
# [120]	validation-rmse:6.37496
# [121]	validation-rmse:6.37452
# [122]	validation-rmse:6.37402
# [123]	validation-rmse:6.37330
# [124]	validation-rmse:6.37287
# [125]	validation-rmse:6.37257
# [126]	validation-rmse:6.37183
# [127]	validation-rmse:6.37158
# [128]	validation-rmse:6.37101
# [129]	validation-rmse:6.37057
# [130]	validation-rmse:6.36983
# [131]	validation-rmse:6.36935
# [132]	validation-rmse:6.36887
# [133]	validation-rmse:6.36881
# [134]	validation-rmse:6.36840
# [135]	validation-rmse:6.36818
# [136]	validation-rmse:6.36784
# [137]	validation-rmse:6.36739
# [138]	validation-rmse:6.36647
# [139]	validation-rmse:6.36582
# [140]	validation-rmse:6.36547
# [141]	validation-rmse:6.36505
# [142]	validation-rmse:6.36515
# [143]	validation-rmse:6.36464
# [144]	validation-rmse:6.36424
# [145]	validation-rmse:6.36390
# [146]	validation-rmse:6.36334
# [147]	validation-rmse:6.36307
# [148]	validation-rmse:6.36317
# [149]	validation-rmse:6.36290
# [150]	validation-rmse:6.36259
# [151]	validation-rmse:6.36216
# [152]	validation-rmse:6.36153
# [153]	validation-rmse:6.36115
# [154]	validation-rmse:6.36072
# [155]	validation-rmse:6.35994
# [156]	validation-rmse:6.35952
# [157]	validation-rmse:6.35890
# [158]	validation-rmse:6.35861
# [159]	validation-rmse:6.35838
# [160]	validation-rmse:6.35798
# [161]	validation-rmse:6.35750
# [162]	validation-rmse:6.35724
# [163]	validation-rmse:6.35698
# [164]	validation-rmse:6.35645
# [165]	validation-rmse:6.35593
# [166]	validation-rmse:6.35522
# [167]	validation-rmse:6.35478
# [168]	validation-rmse:6.35428
# [169]	validation-rmse:6.35398
# [170]	validation-rmse:6.35349
# [171]	validation-rmse:6.35312
# [172]	validation-rmse:6.35278
# [173]	validation-rmse:6.35250
# [174]	validation-rmse:6.35244
# [175]	validation-rmse:6.35210
# [176]	validation-rmse:6.35174
# [177]	validation-rmse:6.35107
# [178]	validation-rmse:6.35080
# [179]	validation-rmse:6.35069
# [180]	validation-rmse:6.35006
# [181]	validation-rmse:6.34962
# [182]	validation-rmse:6.34937
# [183]	validation-rmse:6.34909
# [184]	validation-rmse:6.34879
# [185]	validation-rmse:6.34889
# [186]	validation-rmse:6.34860
# [187]	validation-rmse:6.34831
# [188]	validation-rmse:6.34822
# [189]	validation-rmse:6.34738
# [190]	validation-rmse:6.34650
# [191]	validation-rmse:6.34636
# [192]	validation-rmse:6.34614
# [193]	validation-rmse:6.34588
# [194]	validation-rmse:6.34513
# [195]	validation-rmse:6.34501
# [196]	validation-rmse:6.34481
# [197]	validation-rmse:6.34459
# [198]	validation-rmse:6.34435
# [199]	validation-rmse:6.34413
# [200]	validation-rmse:6.34403
# [201]	validation-rmse:6.34364
# [202]	validation-rmse:6.34380
# [203]	validation-rmse:6.34339
# [204]	validation-rmse:6.34300
# [205]	validation-rmse:6.34275
# [206]	validation-rmse:6.34236
# [207]	validation-rmse:6.34194
# [208]	validation-rmse:6.34189
# [209]	validation-rmse:6.34181
# [210]	validation-rmse:6.34146
# [211]	validation-rmse:6.34131
# [212]	validation-rmse:6.34117
# [213]	validation-rmse:6.34081
# [214]	validation-rmse:6.34077
# [215]	validation-rmse:6.34054
# [216]	validation-rmse:6.34057
# [217]	validation-rmse:6.34008
# [218]	validation-rmse:6.33983
# [219]	validation-rmse:6.33967
# [220]	validation-rmse:6.33950
# [221]	validation-rmse:6.33918
# [222]	validation-rmse:6.33868
# [223]	validation-rmse:6.33837
# [224]	validation-rmse:6.33767
# [225]	validation-rmse:6.33733
# [226]	validation-rmse:6.33744
# [227]	validation-rmse:6.33750
# [228]	validation-rmse:6.33728
# [229]	validation-rmse:6.33714
# [230]	validation-rmse:6.33657
# [231]	validation-rmse:6.33631
# [232]	validation-rmse:6.33585
# [233]	validation-rmse:6.33543
# [234]	validation-rmse:6.33506
# [235]	validation-rmse:6.33497
# [236]	validation-rmse:6.33464
# [237]	validation-rmse:6.33443
# [238]	validation-rmse:6.33431
# [239]	validation-rmse:6.33370
# [240]	validation-rmse:6.33350
# [241]	validation-rmse:6.33323
# [242]	validation-rmse:6.33308
# [243]	validation-rmse:6.33270
# [244]	validation-rmse:6.33249
# [245]	validation-rmse:6.33200
# [246]	validation-rmse:6.33170
# [247]	validation-rmse:6.33161
# [248]	validation-rmse:6.33134
# [249]	validation-rmse:6.33134
# [250]	validation-rmse:6.33117
# [251]	validation-rmse:6.33082
# [252]	validation-rmse:6.33052
# [253]	validation-rmse:6.33012
# [254]	validation-rmse:6.32995
# [255]	validation-rmse:6.32980
# [256]	validation-rmse:6.32884
# [257]	validation-rmse:6.32876
# [258]	validation-rmse:6.32876
# [259]	validation-rmse:6.32855
# [260]	validation-rmse:6.32843
# [261]	validation-rmse:6.32773
# [262]	validation-rmse:6.32740
# [263]	validation-rmse:6.32709
# [264]	validation-rmse:6.32711
# [265]	validation-rmse:6.32661
# [266]	validation-rmse:6.32638
# [267]	validation-rmse:6.32596
# [268]	validation-rmse:6.32574
# [269]	validation-rmse:6.32606
# [270]	validation-rmse:6.32602
# [271]	validation-rmse:6.32568
# [272]	validation-rmse:6.32569
# [273]	validation-rmse:6.32554
# [274]	validation-rmse:6.32513
# [275]	validation-rmse:6.32491
# [276]	validation-rmse:6.32475
# [277]	validation-rmse:6.32456
# [278]	validation-rmse:6.32445
# [279]	validation-rmse:6.32416
# [280]	validation-rmse:6.32411
# [281]	validation-rmse:6.32362
# [282]	validation-rmse:6.32338
# [283]	validation-rmse:6.32330
# [284]	validation-rmse:6.32302
# [285]	validation-rmse:6.32287
# [286]	validation-rmse:6.32279
# [287]	validation-rmse:6.32267
# [288]	validation-rmse:6.32271
# [289]	validation-rmse:6.32256
# [290]	validation-rmse:6.32249
# [291]	validation-rmse:6.32252
# [292]	validation-rmse:6.32228
# [293]	validation-rmse:6.32213
# [294]	validation-rmse:6.32190
# [295]	validation-rmse:6.32174
# [296]	validation-rmse:6.32145
# [297]	validation-rmse:6.32128
# [298]	validation-rmse:6.32104
# [299]	validation-rmse:6.32018
# [300]	validation-rmse:6.31982
# [301]	validation-rmse:6.31982
# [302]	validation-rmse:6.31997
# [303]	validation-rmse:6.31992
# [304]	validation-rmse:6.31978
# [305]	validation-rmse:6.31991
# [306]	validation-rmse:6.32003
# [307]	validation-rmse:6.31991
# [308]	validation-rmse:6.31994
# [309]	validation-rmse:6.31951
# [310]	validation-rmse:6.31911
# [311]	validation-rmse:6.31886
# [312]	validation-rmse:6.31880
# [313]	validation-rmse:6.31857
# [314]	validation-rmse:6.31809
# [315]	validation-rmse:6.31810
# [316]	validation-rmse:6.31804
# [317]	validation-rmse:6.31781
# [318]	validation-rmse:6.31773
# [319]	validation-rmse:6.31751
# [320]	validation-rmse:6.31673
# [321]	validation-rmse:6.31684
# [322]	validation-rmse:6.31677
# [323]	validation-rmse:6.31651
# [324]	validation-rmse:6.31634
# [325]	validation-rmse:6.31586
# [326]	validation-rmse:6.31556
# [327]	validation-rmse:6.31579
# [328]	validation-rmse:6.31576
# [329]	validation-rmse:6.31538
# [330]	validation-rmse:6.31553
# [331]	validation-rmse:6.31520
# [332]	validation-rmse:6.31497
# [333]	validation-rmse:6.31481
# [334]	validation-rmse:6.31491
# [335]	validation-rmse:6.31482
# [336]	validation-rmse:6.31462
# [337]	validation-rmse:6.31471
# [338]	validation-rmse:6.31466
# [339]	validation-rmse:6.31460
# [340]	validation-rmse:6.31417
# [341]	validation-rmse:6.31408
# [342]	validation-rmse:6.31386
# [343]	validation-rmse:6.31393
# [344]	validation-rmse:6.31364
# [345]	validation-rmse:6.31354
# [346]	validation-rmse:6.31315
# [347]	validation-rmse:6.31328
# [348]	validation-rmse:6.31315
# [349]	validation-rmse:6.31324
# [350]	validation-rmse:6.31309
# [351]	validation-rmse:6.31297
# [352]	validation-rmse:6.31275
# [353]	validation-rmse:6.31275
# [354]	validation-rmse:6.31247
# [355]	validation-rmse:6.31210
# [356]	validation-rmse:6.31198
# [357]	validation-rmse:6.31157
# [358]	validation-rmse:6.31162
# [359]	validation-rmse:6.31188
# [360]	validation-rmse:6.31164
# [361]	validation-rmse:6.31163
# [362]	validation-rmse:6.31170
# [363]	validation-rmse:6.31156
# [364]	validation-rmse:6.31121
# [365]	validation-rmse:6.31103
# [366]	validation-rmse:6.31093
# [367]	validation-rmse:6.31084
# [368]	validation-rmse:6.31007
# [369]	validation-rmse:6.30929
# [370]	validation-rmse:6.30926
# [371]	validation-rmse:6.30918
# [372]	validation-rmse:6.30896
# [373]	validation-rmse:6.30872
# [374]	validation-rmse:6.30867
# [375]	validation-rmse:6.30872
# [376]	validation-rmse:6.30857
# [377]	validation-rmse:6.30839
# [378]	validation-rmse:6.30843
# [379]	validation-rmse:6.30838
# [380]	validation-rmse:6.30833
# [381]	validation-rmse:6.30812
# [382]	validation-rmse:6.30812
# [383]	validation-rmse:6.30804
# [384]	validation-rmse:6.30810
# [385]	validation-rmse:6.30803
# [386]	validation-rmse:6.30804
# [387]	validation-rmse:6.30807
# [388]	validation-rmse:6.30802
# [389]	validation-rmse:6.30804
# [390]	validation-rmse:6.30797
# [391]	validation-rmse:6.30802
# [392]	validation-rmse:6.30779
# [393]	validation-rmse:6.30760
# [394]	validation-rmse:6.30746
# [395]	validation-rmse:6.30748
# [396]	validation-rmse:6.30715
# [397]	validation-rmse:6.30698
# [398]	validation-rmse:6.30688
# [399]	validation-rmse:6.30682
# [400]	validation-rmse:6.30678
# [401]	validation-rmse:6.30665
# [402]	validation-rmse:6.30605
# [403]	validation-rmse:6.30608
# [404]	validation-rmse:6.30597
# [405]	validation-rmse:6.30587
# [406]	validation-rmse:6.30568
# [407]	validation-rmse:6.30589
# [408]	validation-rmse:6.30571
# [409]	validation-rmse:6.30502
# [410]	validation-rmse:6.30504
# [411]	validation-rmse:6.30503
# [412]	validation-rmse:6.30478
# [413]	validation-rmse:6.30466
# [414]	validation-rmse:6.30457
# [415]	validation-rmse:6.30455
# [416]	validation-rmse:6.30438
# [417]	validation-rmse:6.30453
# [418]	validation-rmse:6.30431
# [419]	validation-rmse:6.30422
# [420]	validation-rmse:6.30440
# [421]	validation-rmse:6.30437
# [422]	validation-rmse:6.30416
# [423]	validation-rmse:6.30406
# [424]	validation-rmse:6.30392
# [425]	validation-rmse:6.30407
# [426]	validation-rmse:6.30411
# [427]	validation-rmse:6.30436
# [428]	validation-rmse:6.30424
# [429]	validation-rmse:6.30411
# [430]	validation-rmse:6.30403
# [431]	validation-rmse:6.30406
# [432]	validation-rmse:6.30418
# [433]	validation-rmse:6.30404
# [434]	validation-rmse:6.30386
# [435]	validation-rmse:6.30380
# [436]	validation-rmse:6.30358
# [437]	validation-rmse:6.30341
# [438]	validation-rmse:6.30339
# [439]	validation-rmse:6.30330
# [440]	validation-rmse:6.30331
# [441]	validation-rmse:6.30306
# [442]	validation-rmse:6.30340
# [443]	validation-rmse:6.30295
# [444]	validation-rmse:6.30270
# [445]	validation-rmse:6.30279
# [446]	validation-rmse:6.30266
# [447]	validation-rmse:6.30285
# [448]	validation-rmse:6.30278
# [449]	validation-rmse:6.30264
# [450]	validation-rmse:6.30267
# [451]	validation-rmse:6.30270
# [452]	validation-rmse:6.30244
# [453]	validation-rmse:6.30244
# [454]	validation-rmse:6.30247
# [455]	validation-rmse:6.30244
# [456]	validation-rmse:6.30248
# [457]	validation-rmse:6.30252
# [458]	validation-rmse:6.30255
# [459]	validation-rmse:6.30251
# [460]	validation-rmse:6.30241
# [461]	validation-rmse:6.30234
# [462]	validation-rmse:6.30197
# [463]	validation-rmse:6.30191
# [464]	validation-rmse:6.30182
# [465]	validation-rmse:6.30173
# [466]	validation-rmse:6.30195
# [467]	validation-rmse:6.30193
# [468]	validation-rmse:6.30176
# [469]	validation-rmse:6.30160
# [470]	validation-rmse:6.30152
# [471]	validation-rmse:6.30158
# [472]	validation-rmse:6.30176
# [473]	validation-rmse:6.30179
# [474]	validation-rmse:6.30152
# [475]	validation-rmse:6.30145
# [476]	validation-rmse:6.30130
# [477]	validation-rmse:6.30133
# [478]	validation-rmse:6.30125
# [479]	validation-rmse:6.30120
# [480]	validation-rmse:6.30133
# [481]	validation-rmse:6.30119
# [482]	validation-rmse:6.30112
# [483]	validation-rmse:6.30100
# [484]	validation-rmse:6.30104
# [485]	validation-rmse:6.30116
# [486]	validation-rmse:6.30109
# [487]	validation-rmse:6.30119
# [488]	validation-rmse:6.30102
# [489]	validation-rmse:6.30075
# [490]	validation-rmse:6.30062
# [491]	validation-rmse:6.30050
# [492]	validation-rmse:6.30040
# [493]	validation-rmse:6.30030
# [494]	validation-rmse:6.30021
# [495]	validation-rmse:6.30010
# [496]	validation-rmse:6.30011
# [497]	validation-rmse:6.30035
# [498]	validation-rmse:6.30041
# [499]	validation-rmse:6.30043
# [500]	validation-rmse:6.30050
# [501]	validation-rmse:6.30052
# [502]	validation-rmse:6.30016
# [503]	validation-rmse:6.30013
# [504]	validation-rmse:6.30010
# [505]	validation-rmse:6.29970
# [506]	validation-rmse:6.29998
# [507]	validation-rmse:6.29999
# [508]	validation-rmse:6.30010
# [509]	validation-rmse:6.29978
# [510]	validation-rmse:6.29985
# [511]	validation-rmse:6.29981
# [512]	validation-rmse:6.29987
# [513]	validation-rmse:6.29971
# [514]	validation-rmse:6.29918
# [515]	validation-rmse:6.29900
# [516]	validation-rmse:6.29899
# [517]	validation-rmse:6.29918
# [518]	validation-rmse:6.29933
# [519]	validation-rmse:6.29917
# [520]	validation-rmse:6.29919
# [521]	validation-rmse:6.29937
# [522]	validation-rmse:6.29959
# [523]	validation-rmse:6.29991
# [524]	validation-rmse:6.29984
# [525]	validation-rmse:6.29983
# [526]	validation-rmse:6.29942
# [527]	validation-rmse:6.29945
# [528]	validation-rmse:6.29934
# [529]	validation-rmse:6.29942
# [530]	validation-rmse:6.29939
# [531]	validation-rmse:6.29930
# [532]	validation-rmse:6.29917
# [533]	validation-rmse:6.29878
# [534]	validation-rmse:6.29876
# [535]	validation-rmse:6.29871
# [536]	validation-rmse:6.29856
# [537]	validation-rmse:6.29834
# [538]	validation-rmse:6.29826
# [539]	validation-rmse:6.29833
# [540]	validation-rmse:6.29854
# [541]	validation-rmse:6.29846
# [542]	validation-rmse:6.29851
# [543]	validation-rmse:6.29845
# [544]	validation-rmse:6.29863
# [545]	validation-rmse:6.29878
# [546]	validation-rmse:6.29868
# [547]	validation-rmse:6.29874
# [548]	validation-rmse:6.29914
# [549]	validation-rmse:6.29919
# [550]	validation-rmse:6.29920
# [551]	validation-rmse:6.29926
# [552]	validation-rmse:6.29906
# [553]	validation-rmse:6.29921
# [554]	validation-rmse:6.29893
# [555]	validation-rmse:6.29893
# [556]	validation-rmse:6.29893
# [557]	validation-rmse:6.29884
# [558]	validation-rmse:6.29878
# [559]	validation-rmse:6.29891
# [560]	validation-rmse:6.29887
# [561]	validation-rmse:6.29895
# [562]	validation-rmse:6.29896
# [563]	validation-rmse:6.29877
# [564]	validation-rmse:6.29875
# [565]	validation-rmse:6.29859
# [566]	validation-rmse:6.29853
# [567]	validation-rmse:6.29840
# [568]	validation-rmse:6.29843
# [569]	validation-rmse:6.29852
# [570]	validation-rmse:6.29825
# [571]	validation-rmse:6.29800
# [572]	validation-rmse:6.29816
# [573]	validation-rmse:6.29810
# [574]	validation-rmse:6.29815
# [575]	validation-rmse:6.29835
# [576]	validation-rmse:6.29852
# [577]	validation-rmse:6.29853
# [578]	validation-rmse:6.29853
# [579]	validation-rmse:6.29841
# [580]	validation-rmse:6.29832
# [581]	validation-rmse:6.29819
# [582]	validation-rmse:6.29830
# [583]	validation-rmse:6.29841
# [584]	validation-rmse:6.29868
# [585]	validation-rmse:6.29880
# [586]	validation-rmse:6.29875
# [587]	validation-rmse:6.29860
# [588]	validation-rmse:6.29874
# [589]	validation-rmse:6.29868
# [590]	validation-rmse:6.29872
# [591]	validation-rmse:6.29879
# [592]	validation-rmse:6.29868
# [593]	validation-rmse:6.29860
# [594]	validation-rmse:6.29860
# [595]	validation-rmse:6.29868
# [596]	validation-rmse:6.29870
# [597]	validation-rmse:6.29867
# [598]	validation-rmse:6.29851
# [599]	validation-rmse:6.29859
# [600]	validation-rmse:6.29855
# [601]	validation-rmse:6.29856
# [602]	validation-rmse:6.29861
# [603]	validation-rmse:6.29863
# [604]	validation-rmse:6.29872
# [605]	validation-rmse:6.29856
# [606]	validation-rmse:6.29825
# [607]	validation-rmse:6.29808
# [608]	validation-rmse:6.29804
# [609]	validation-rmse:6.29799
# [610]	validation-rmse:6.29813
# [611]	validation-rmse:6.29817
# [612]	validation-rmse:6.29845
# [613]	validation-rmse:6.29833
# [614]	validation-rmse:6.29831
# [615]	validation-rmse:6.29821
# [616]	validation-rmse:6.29822
# [617]	validation-rmse:6.29820
# [618]	validation-rmse:6.29829
# [619]	validation-rmse:6.29831
# [620]	validation-rmse:6.29850
# [621]	validation-rmse:6.29860
# [622]	validation-rmse:6.29855
# [623]	validation-rmse:6.29858
# [624]	validation-rmse:6.29864
# [625]	validation-rmse:6.29876
# [626]	validation-rmse:6.29878
# [627]	validation-rmse:6.29877
# [628]	validation-rmse:6.29884
# [629]	validation-rmse:6.29883
# [630]	validation-rmse:6.29863
# [631]	validation-rmse:6.29871
# [632]	validation-rmse:6.29892
# [633]	validation-rmse:6.29896
# [634]	validation-rmse:6.29884
# [635]	validation-rmse:6.29882
# [636]	validation-rmse:6.29878
# [637]	validation-rmse:6.29859
# [638]	validation-rmse:6.29853
# [639]	validation-rmse:6.29854
# [640]	validation-rmse:6.29840
# [641]	validation-rmse:6.29830
# [642]	validation-rmse:6.29829
# [643]	validation-rmse:6.29818
# [644]	validation-rmse:6.29831
# [645]	validation-rmse:6.29833
# [646]	validation-rmse:6.29832
# [647]	validation-rmse:6.29836
# [648]	validation-rmse:6.29824
# [649]	validation-rmse:6.29830
# [650]	validation-rmse:6.29836
# [651]	validation-rmse:6.29835
# [652]	validation-rmse:6.29837
# [653]	validation-rmse:6.29844
# [654]	validation-rmse:6.29829
# [655]	validation-rmse:6.29818
# [656]	validation-rmse:6.29813
# [657]	validation-rmse:6.29815
# [658]	validation-rmse:6.29809
# /Users/matthiasmotl/opt/anaconda3/envs/experiment_tracking/lib/python3.9/site-packages/xgboost/core.py:160: UserWarning: [14:28:38] WARNING: /Users/runner/miniforge3/conda-bld/xgboost-split_1703076406455/work/src/c_api/c_api.cc:1240: Saving into deprecated binary model format, please consider using `json` or `ubj`. Model format will default to JSON in XGBoost 2.2 if not specified.
#   warnings.warn(smsg, UserWarning)
# 2025/05/21 14:28:42 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.

# %% [markdown]
# From Artifact:

# %%
# import mlflow
logged_model = 'runs:/3eb110884b3a47fa89c621fac277ba3b/models_mlflow'

# Load model as a PyFuncModel.
loaded_model = mlflow.pyfunc.load_model(logged_model)

# # Predict on a Pandas DataFrame.
# import pandas as pd
# loaded_model.predict(pd.DataFrame(data))
# Out:
# /Users/matthiasmotl/opt/anaconda3/envs/experiment_tracking/lib/python3.9/site-packages/xgboost/core.py:160: UserWarning: [14:36:13] WARNING: /Users/runner/miniforge3/conda-bld/xgboost-split_1703076406455/work/src/objective/regression_obj.cu:209: reg:linear is now deprecated in favor of reg:squarederror.
#   warnings.warn(smsg, UserWarning)

# %%
loaded_model
# Out:
# mlflow.pyfunc.loaded_model:
#   artifact_path: models_mlflow
#   flavor: mlflow.xgboost
#   run_id: 3eb110884b3a47fa89c621fac277ba3b

# %%
xgboost_model = mlflow.xgboost.load_model(logged_model) #logged_model is the URI logged_model = 'runs:/3eb110884b3a47fa89c621fac277ba3b/models_mlflow'
# Out:
# /Users/matthiasmotl/opt/anaconda3/envs/experiment_tracking/lib/python3.9/site-packages/xgboost/core.py:160: UserWarning: [14:37:33] WARNING: /Users/runner/miniforge3/conda-bld/xgboost-split_1703076406455/work/src/objective/regression_obj.cu:209: reg:linear is now deprecated in favor of reg:squarederror.
#   warnings.warn(smsg, UserWarning)

# %%
xgboost_model

# %%
y_pred = xgboost_model.predict(valid)

# %%
y_pred
# Out:
# array([14.422415 ,  7.131102 , 14.262912 , ..., 13.464924 ,  6.0386367,
#         8.0312605], dtype=float32)

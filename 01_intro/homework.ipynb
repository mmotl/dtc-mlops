# %%
import pandas as pd
from sklearn.feature_extraction import DictVectorizer
from sklearn.metrics import mean_squared_error

import seaborn as sns
import matplotlib.pyplot as plt

# %%
def df_features(data, to_encode):
    '''function to prepare the dataframe for recurring use, eg. creating a validation dataset
       returns X and y
       
       data = path to data, STR
       to_encode = list of columns to encode as X features

       use:
       X, y = df_features('path', to_encode)
    '''

    df = pd.read_parquet(data)
    df['duration'] = df.tpep_dropoff_datetime - df.tpep_pickup_datetime
    df['duration'] = df['duration'].apply(lambda x: x.total_seconds()/60)
    df = df[(df.duration >= 1) & (df.duration <= 60)]
    df[to_encode] = df[to_encode].astype(str)
    return df[to_encode], df.duration

# %% [markdown]
# #### granular steps to answer homework questions:

# %% [markdown]
# ##### Q1: Downloading the data
# 19 Columns

# %%
df = pd.read_parquet('data/yellow_tripdata_2023-01.parquet')
df.head()
# Out:
#    VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0         2  2023-01-01 00:32:10   2023-01-01 00:40:36              1.0
# 1         2  2023-01-01 00:55:08   2023-01-01 01:01:27              1.0
# 2         2  2023-01-01 00:25:04   2023-01-01 00:37:49              1.0
# 3         1  2023-01-01 00:03:48   2023-01-01 00:13:25              0.0
# 4         2  2023-01-01 00:10:29   2023-01-01 00:21:19              1.0
#
#    trip_distance  RatecodeID store_and_fwd_flag  PULocationID  DOLocationID  \
# 0           0.97         1.0                  N           161           141
# 1           1.10         1.0                  N            43           237
# 2           2.51         1.0                  N            48           238
# 3           1.90         1.0                  N           138             7
# 4           1.43         1.0                  N           107            79
#
#    payment_type  fare_amount  extra  mta_tax  tip_amount  tolls_amount  \
# ...

# %%
df.info()
pre_clean = df.shape[0]
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3066766 entries, 0 to 3066765
# Data columns (total 19 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   VendorID               int64
#  1   tpep_pickup_datetime   datetime64[ns]
#  2   tpep_dropoff_datetime  datetime64[ns]
#  3   passenger_count        float64
#  4   trip_distance          float64
#  5   RatecodeID             float64
#  6   store_and_fwd_flag     object
#  7   PULocationID           int64
#  8   DOLocationID           int64
#  9   payment_type           int64
#  10  fare_amount            float64
#  11  extra                  float64
#  12  mta_tax                float64
#  13  tip_amount             float64
#  14  tolls_amount           float64
#  15  improvement_surcharge  float64
#  16  total_amount           float64
#  17  congestion_surcharge   float64
#  18  airport_fee            float64
# dtypes: datetime64[ns](2), float64(12), int64(4), object(1)
# ...

# %% [markdown]
# ##### Q2. Computing duration:
# stdev 42.59435124195458

# %%
df['duration'] = df.tpep_dropoff_datetime - df.tpep_pickup_datetime
df.duration[:5]
# Out:
# 0   0 days 00:08:26
# 1   0 days 00:06:19
# 2   0 days 00:12:45
# 3   0 days 00:09:37
# 4   0 days 00:10:50
# Name: duration, dtype: timedelta64[ns]

# %%
df['duration'] = df['duration'].apply(lambda x: x.total_seconds()/60)

# %%
df.duration.std()
# Out:
# 42.59435124195458

# %%
df.duration.info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 3066766 entries, 0 to 3066765
# Series name: duration
# Non-Null Count    Dtype
# --------------    -----
# 3066766 non-null  float64
# dtypes: float64(1)
# memory usage: 23.4 MB

# %% [markdown]
# ##### Q3. Dropping outliers:
# 98%

# %%
df = df[(df.duration >= 1) & (df.duration <= 60)]

# %%
df.duration.info()
# Out:
# <class 'pandas.core.series.Series'>
# Int64Index: 3009173 entries, 0 to 3066765
# Series name: duration
# Non-Null Count    Dtype
# --------------    -----
# 3009173 non-null  float64
# dtypes: float64(1)
# memory usage: 45.9 MB

# %%
post_clean = df.shape[0]

# %%
round((post_clean / pre_clean), 2)
# Out:
# 0.98

# %% [markdown]
# ##### Q4. One-hot encoding:
# Columns: 515

# %%
# Let's apply one-hot encoding to the pickup and dropoff location IDs. We'll use only these two features for our model.
# Turn the dataframe into a list of dictionaries (remember to re-cast the ids to strings - otherwise it will label encode them)

to_encode = ['PULocationID', 'DOLocationID']
df[to_encode] = df[to_encode].astype(str)
dicts = df[to_encode].to_dict(orient='records')

# %%
dv = DictVectorizer()

# %%
# Fit a dictionary vectorizer
# Get a feature matrix from it

X = dv.fit_transform(dicts)

# %%
X.shape
# Out:
# (3009173, 515)

# %% [markdown]
# ##### Q5. Training a model:
# RMSE 7.649262776520412

# %% [markdown]
# Now let's use the feature matrix from the previous step to train a model.
#
# Train a plain linear regression model with default parameters, where duration is the response variable
# Calculate the RMSE of the model on the training data

# %%
from sklearn.linear_model import LinearRegression

# %%
lr_model = LinearRegression()

# %%
y = df.duration

# %%
lr_model.fit(X, y)
# Out:
# LinearRegression()

# %%
y_pred = lr_model.predict(X)

# %%
mean_squared_error(y, y_pred, squared=False)
# Out:
# 7.649262776520412

# %%
sns.kdeplot(y_pred, label='train pred') 
# sns.kdeplot(y_pred_train, label='y_train')  
sns.kdeplot(y, label='train actual') 
plt.legend()

# %% [markdown]
# ##### Q6. Evaluating the model:
# RMSE: 7.811802649882949

# %%
# Now let's apply this model to the validation dataset (February 2023).
# What's the RMSE on validation?

df_val, y_val = df_features('data/yellow_tripdata_2023-02.parquet', to_encode)
df_val.head(2)
# Out:
#   PULocationID DOLocationID
# 0          142          163
# 3          132           26

# %%
dicts_val = df_val.to_dict(orient='records')
X_val = dv.transform(dicts_val)
X_val
# Out:
# <2855951x515 sparse matrix of type '<class 'numpy.float64'>'
# 	with 5711894 stored elements in Compressed Sparse Row format>

# %%
y_val
# Out:
# 0           1.683333
# 3          32.083333
# 4          13.300000
# 5          14.633333
# 6          27.950000
#              ...
# 2913950    19.000000
# 2913951    11.133333
# 2913952    14.000000
# 2913953     7.000000
# 2913954     9.800000
# Name: duration, Length: 2855951, dtype: float64

# %%
y_val_pred = lr_model.predict(X_val)

# %%
mean_squared_error(y_val_pred, y_val, squared=False)
# Out:
# 7.811802649882949

# %%
sns.kdeplot(y_val_pred, label='train pred') 
# sns.kdeplot(y_pred_train, label='y_train')  
sns.kdeplot(y_val, label='train actual') 
plt.legend()
